# %% [markdown]
# ***data preprocessing***

# %% [markdown]
# 11 attributes.
#
# Bu özniteliklerden ID, her bir kayıt için
# verilen numaradır.
#
# Diğer öznitelikler bir yaşam ortamına ait ölçüm değerlerini vermektedir.
#
# Sınıf bilgisi ise bu ölçüm değerlerine göre bir ortamın yaşanır olup olmadığını göstermektedir.
#
# İlgili veri kümesinin mümkün olduğu kadar hatalardan ayıklanması ve analize hazır en uygun şekle getirilmesi gerekmektedir.
#
# Bu nedenle:
# Veri kümesi üzerinde Veri Özetleme ve Veri Ön İşleme Adımları’ndan gerekli gördüklerinizi
# uygulamanız beklenmektedir.
#
#
# > *Veri üzerinde uyguladığınız adımların detaylarını, verinin nasıl değiştiğini*
#
# > *Herhangi bir adımda, uygulanabilecek birden fazla yöntem var ise, hangi yöntemi ne
# için seçtiğinizin, diğer yöntemi niçin seçmediğinizin kısa bir açıklamasını yapınız. *
#
# > *Atladığınız veya yapılmasını gerek görmediğiniz adımları niçin uygulamadığınızı
# kısaca açıklayınız.*
#
# > *Rapor içerisinde bir veriye referans verirken ham veri kümesinde ID bilgisini
# kullanmalısınız. Örneğin: ID=20 olan verinin polarite değeri vb.*

# %%
import numpy as np
import pandas as pd
import os
import matplotlib

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-483de31e-2100-4fe8-b156-0d05af593ab8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-483de31e-2100-4fe8-b156-0d05af593ab8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Proje1_VeriKümesi.csv")
df
# Out:
#        ID  Densite  Polarite  H20_Skoru  O2_Skoru  Azot_Skoru  H20_Oranı  \
# 0    44.0     0.91      4.40        0.9      9.79        9.70      11.00
# 1    19.0     1.64     -0.78        0.9      8.63        0.08       9.70
# 2    79.0     0.63       NaN        5.2      7.65        4.10       1.50
# 3    10.0     0.67       NaN        4.9      7.20        3.10       1.50
# 4    14.0     0.56       NaN        4.8      6.58        3.00       1.40
# ..    ...      ...       ...        ...       ...         ...        ...
# 149  53.0    -0.32       NaN        0.9     -0.13        9.70       0.02
# 150  55.0    -1.11       NaN        NaN    -10.44        2.50       5.80
# 151  80.0     0.98     -0.45        0.9     -0.20        0.08       0.02
# 152  73.0     0.76      1.32        5.0      8.00        3.40       1.60
# 153  74.0     0.69      1.41        5.2      7.80        3.50       1.50
#
#      O2_Oranı  Azot_Oranı  Kaynaklar  Isı_Oranı Sınıf Bilgisi
# ...
